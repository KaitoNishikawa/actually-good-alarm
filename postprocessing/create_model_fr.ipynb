# %%
import pandas as pd
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

# %%
df = pd.read_csv("46343.csv")
df2 = pd.read_csv("759667.csv")

combined_df = pd.concat([df, df2], ignore_index=True)

# %%
x = combined_df[['cosine_feature', 'count_feature', 'hr_feature', 'time_feature']]
y = combined_df['psg_label']

# %%
x
# Out:
#       cosine_feature  count_feature  hr_feature  time_feature
# 0          -0.258819      38.634412    0.524519      0.000000
# 1          -0.260926      31.640606    0.514774      0.008333
# 2          -0.263031      22.570999    0.497230      0.016667
# 3          -0.265135      19.341522    0.489079      0.025000
# 4          -0.267238      21.960207    0.482398      0.033333
# ...              ...            ...         ...           ...
# 1000       -0.958820       0.288989    0.670869      3.900000
# 1001       -0.959437       0.562428    0.693712      3.908333
# 1002       -0.960050       1.016407    0.717479      3.916667
# 1003       -0.960658       1.695372    0.742948      3.925000
# 1004       -0.961262       2.609195    0.742233      3.933333
#
# [1005 rows x 4 columns]

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1000    5
# 1001    1
# 1002    0
# 1003    1
# 1004    1
# Name: psg_label, Length: 1005, dtype: int64

# %%
clf = RandomForestClassifier()

# %%
clf.fit(x,y)
# Out:
# RandomForestClassifier()

# %%
clf.feature_importances_
# Out:
# array([0.3183514 , 0.09478723, 0.25038002, 0.33648135])

# %%
x.columns
# Out:
# Index(['cosine_feature', 'count_feature', 'hr_feature', 'time_feature'], dtype='object')

# %%
x.iloc[300]
# Out:
# cosine_feature   -0.793353
# count_feature     0.292421
# hr_feature        0.445532
# time_feature      2.500000
# Name: 300, dtype: float64

# %%
result = clf.predict([x.iloc[300]])

result
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([3])

# %%
y.iloc[300]
# Out:
# 3

# %%
# See which classes the model found and their order
print("Classes (in order):", clf.classes_)
print("Probabilities:", clf.predict_proba([x.iloc[300]]))
# Out:
# Classes (in order): [0 1 2 3 5]
# Probabilities: [[0.   0.   0.22 0.77 0.01]]
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
x_train.shape, y_train.shape
# Out:
# ((804, 4), (804,))

# %%
x_test.shape, y_test.shape
# Out:
# ((201, 4), (201,))

# %%
clf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
print(clf.predict_proba([x.iloc[300]]))
# Out:
# [[0.   0.   0.17 0.83 0.  ]]
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
print(clf.predict(x_test))
# Out:
# [5 2 0 0 2 3 1 2 3 5 2 5 5 2 3 2 3 0 2 1 3 3 5 1 5 2 3 5 0 5 5 5 5 0 2 3 3
#  0 2 2 5 5 2 2 5 2 3 3 0 5 2 2 3 3 2 0 2 5 3 3 2 3 3 3 2 3 5 2 3 2 2 2 2 5
#  5 3 1 3 2 5 5 5 2 5 2 2 3 5 2 3 5 3 2 3 5 0 5 3 3 5 5 3 3 2 5 5 3 5 5 3 5
#  2 2 3 2 5 3 2 3 3 2 3 5 3 3 2 3 5 3 3 2 2 3 3 0 3 2 3 2 5 5 1 0 3 2 2 3 3
#  2 3 2 2 5 3 5 3 5 2 2 2 2 3 5 3 2 3 2 3 2 5 5 2 2 2 2 3 2 3 0 3 5 2 5 0 5
#  0 5 5 3 0 5 2 2 5 5 3 5 5 0 3 3]

# %%
print(y_test)
# Out:
# 349    5
# 33     0
# 112    0
# 27     0
# 222    2
#       ..
# 175    5
# 942    5
# 990    5
# 629    3
# 640    3
# Name: psg_label, Length: 201, dtype: int64

# %%
print(clf.score(x_test, y_test))
# Out:
# 0.845771144278607
